# %% [markdown]
# <a href="https://colab.research.google.com/github/Ximenaloranca/Ecuaciones-Diferenciales-Parciales-/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import symbols
from sympy.matrices import Matrix
# c, d, e = symbols("c,d,e")
A = Matrix ([
    [3,-1,0,0,0,0,0,0,0],
    [-1,3,-1,0,0,0,0,0,0],
    [0,-1,3,-1,0,0,0,0,0],
    [0,0,-1,3,-1,0,0,0,0],
    [0,0,0,-1,3,-1,0,0,0],
    [0,0,0,0,-1,3,-1,0,0],
    [0,0,0,0,0,-1,3,-1,0],
    [0,0,0,0,0,0,-1,3,-1],
    [0,0,0,0,0,0,0,-1,3]
    ])
b = Matrix ([0.3090,0.5877,0.8090,0.9510,1.0000,0.9510,0.8090,0.5877,0.3090])
A.LUsolve(b)
# Out:
# Matrix([
# [0.281443902439024],
# [0.535331707317073],
# [0.736851219512195],
# [0.866221951219512],
# [0.910814634146341],
# [0.866221951219512],
# [0.736851219512195],
# [0.535331707317073],
# [0.281443902439024]])
